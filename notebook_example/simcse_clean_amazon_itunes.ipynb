# %%
# !pip install simcse -q

# %%
import os
import sys
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from simcse import SimCSE

# %%
# import model for embeddings 
bert_sup = SimCSE('princeton-nlp/sup-simcse-bert-base-uncased')

# %%
from preprocessing_datasets.preprocessing_itunes_amazon import clean_amazon_itunes
table, pairs = clean_amazon_itunes()

# %%
table.head()
# Out:
#                              Song_Name        Artist_Name  \
# 0                        runaway train                cam
# 1                             track 14                omi
# 2                       lips are movin     meghan trainor
# 3  i want a hippopotamus for christmas  a great big world
# 4                               credit     meghan trainor
#
#                     Album_Name  \
# 0  welcome to cam country - ep
# 1                       me 4 u
# 2                        title
# 3  i 'll be home for christmas
# 4             title ( deluxe )
#
#                                                Genre       Price  \
# 0  country , music , contemporary country , honky...      $ 0.99
# 1        pop/rock , music , pop , dance , r&b / soul  album only
# 2   pop , music , pop/rock , dance , rock , teen pop      $ 1.29
# 3                                    holiday , music      $ 1.29
# 4   pop , music , rock , pop/rock , dance , teen pop      $ 1.29
#
#                                            CopyRight  Time   Released
# 0                      2015 sony music entertainment  3:01  31-mar-15
# 1  2015 ultra records , llc under exclusive licen...  3:41        unk
# 2  2014 , 2015 epic records , a division of sony ...  3:01   9-jan-15
# 3  compilation ( p ) 2014 epic records , a divisi...  2:20  24-nov-14
# 4  2014 , 2015 epic records , a division of sony ...  2:51   9-jan-15

# %%
attributes = ['Song_Name', 'Artist_Name', 'Album_Name']
record_set = table[attributes].agg(' '.join, axis=1)

# %%
start = time.time()
vectors = bert_sup.encode(list(record_set), device="cuda", max_length=256)
print("TIME: {0}".format(time.time() - start))
# Out:
#   0%|                                                                                                                                                                              | 0/982 [00:00<?, ?it/s]/home/bosco/anaconda3/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2227: UserWarning: `max_length` is ignored when `padding`=`True`.
#   warnings.warn("`max_length` is ignored when `padding`=`True`.")
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 982/982 [00:24<00:00, 39.66it/s]
# TIME: 29.063883066177368

# %% [markdown]
# # best run

# %%
algorithm = "louvain"
time_list = []
for num_clusters in [14]*10:
    """loop to evaluate cluster performance"""
    # make imports
    from evaluation import calc_index
    from graph_clustering.knn_graph_clusteriser import all_in_one_clusteriser
    key_values = {}
    print()
    key_values["num_clusters"] = num_clusters
    print(f"building blocks with: ",key_values["num_clusters"], "clusters")
    start = time.time()
    data = all_in_one_clusteriser(vectors, algorithm, num_clusters)
    reduction_ratio,pair_completeness,reference_metric,pair_quality,fmeasure=calc_index(data,table,pairs)
    print("(RR) Reduction ratio is: {0}".format(reduction_ratio))
    print("(PC) Pair completeness is: {0}".format(pair_completeness))
    print("(RM) Reference metric (Harmonic mean RR and PC) is: {0}".format(reference_metric))
    print("(PQ) Pair quality - Precision is: {0}".format(pair_quality))
    print("(FM) Fmeasure is: {0}".format(fmeasure))
    end = time.time()
    blocking_time = end - start
    time_list.append(blocking_time) # blocking time for 30 loops
    print(">> Blocking time was roughly {} seconds for {} tuples!".format(blocking_time,vectors.shape[0]))
    print("*"*50)
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'graph_tool'}
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Note: to be able to use all overlapping methods, you need to install some additional packages:  {'ASLPAw'}
#
# building blocks with:  14 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 626965 edges
# graph constructed in: 144.18136620521545  seconds
# (RR) Reduction ratio is: 0.9925718617389055
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9279408397445579
# (PQ) Pair quality - Precision is: 7.843694137125098e-06
# (FM) Fmeasure is: 1.568724703887866e-05
# >> Blocking time was roughly 156.17388010025024 seconds for 62830 tuples!
# **************************************************
#
# building blocks with:  14 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 626965 edges
# graph constructed in: 144.38652157783508  seconds
# (RR) Reduction ratio is: 0.9925718617389055
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9279408397445579
# (PQ) Pair quality - Precision is: 7.843694137125098e-06
# (FM) Fmeasure is: 1.568724703887866e-05
# >> Blocking time was roughly 160.5944538116455 seconds for 62830 tuples!
# **************************************************
#
# building blocks with:  14 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 626965 edges
# graph constructed in: 144.48831343650818  seconds
# (RR) Reduction ratio is: 0.9925718617389055
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9279408397445579
# (PQ) Pair quality - Precision is: 7.843694137125098e-06
# (FM) Fmeasure is: 1.568724703887866e-05
# >> Blocking time was roughly 161.0458469390869 seconds for 62830 tuples!
# **************************************************
#
# building blocks with:  14 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 626965 edges
# graph constructed in: 145.7030987739563  seconds
# (RR) Reduction ratio is: 0.9925718617389055
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9279408397445579
# (PQ) Pair quality - Precision is: 7.843694137125098e-06
# (FM) Fmeasure is: 1.568724703887866e-05
# >> Blocking time was roughly 161.9388153553009 seconds for 62830 tuples!
# **************************************************
#
# building blocks with:  14 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 626965 edges
# graph constructed in: 146.71675038337708  seconds
# (RR) Reduction ratio is: 0.9925718617389055
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9279408397445579
# (PQ) Pair quality - Precision is: 7.843694137125098e-06
# (FM) Fmeasure is: 1.568724703887866e-05
# >> Blocking time was roughly 163.0242621898651 seconds for 62830 tuples!
# **************************************************
#
# building blocks with:  14 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 626965 edges
# graph constructed in: 145.22348427772522  seconds
# (RR) Reduction ratio is: 0.9925718617389055
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9279408397445579
# (PQ) Pair quality - Precision is: 7.843694137125098e-06
# (FM) Fmeasure is: 1.568724703887866e-05
# >> Blocking time was roughly 161.76990032196045 seconds for 62830 tuples!
# **************************************************
#
# building blocks with:  14 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 626965 edges
# graph constructed in: 144.54065656661987  seconds
# (RR) Reduction ratio is: 0.9925718617389055
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9279408397445579
# (PQ) Pair quality - Precision is: 7.843694137125098e-06
# (FM) Fmeasure is: 1.568724703887866e-05
# >> Blocking time was roughly 160.90353441238403 seconds for 62830 tuples!
# **************************************************
#
# building blocks with:  14 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 626965 edges
# graph constructed in: 145.28521490097046  seconds
# (RR) Reduction ratio is: 0.9925718617389055
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9279408397445579
# (PQ) Pair quality - Precision is: 7.843694137125098e-06
# (FM) Fmeasure is: 1.568724703887866e-05
# >> Blocking time was roughly 161.63031268119812 seconds for 62830 tuples!
# **************************************************
#
# building blocks with:  14 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 626965 edges
# graph constructed in: 143.84574699401855  seconds
# (RR) Reduction ratio is: 0.9925718617389055
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9279408397445579
# (PQ) Pair quality - Precision is: 7.843694137125098e-06
# (FM) Fmeasure is: 1.568724703887866e-05
# >> Blocking time was roughly 160.24036979675293 seconds for 62830 tuples!
# **************************************************
#
# building blocks with:  14 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 626965 edges
# graph constructed in: 145.55208230018616  seconds
# (RR) Reduction ratio is: 0.9925718617389055
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9279408397445579
# (PQ) Pair quality - Precision is: 7.843694137125098e-06
# (FM) Fmeasure is: 1.568724703887866e-05
# >> Blocking time was roughly 162.12055945396423 seconds for 62830 tuples!
# **************************************************

# %%
print("average time :", np.average(time_list))
# Out:
# average time : 160.94419350624085

# %% [markdown]
# # KNN graph clustering
#
# using original vectors

# %% [markdown]
# ### LOUVAIN_clusteriser

# %%
vectors.shape
# Out:
# torch.Size([62830, 768])

# %%
# clusterize using louvain or leiden 
algorithm = "louvain"
dataset = 'DBLP-Scholar-clean'
model = "bert_supCon"
stage = "stage_1"
results = pd.DataFrame()
time_list = []
RR = []
PC = []
RM = []
for num_clusters in range(2,30):
    """loop to evaluate cluster performance"""
    # make imports
    from evaluation import calc_index
    from graph_clustering.knn_graph_clusteriser import all_in_one_clusteriser
    key_values = {}
    print()
    key_values["num_clusters"] = num_clusters
    print(f"building blocks with: {num_clusters} clusters")
    start = time.time()
    data = all_in_one_clusteriser(vectors, algorithm, num_clusters)
    reduction_ratio,pair_completeness,reference_metric,pair_quality,fmeasure=calc_index(data,table,pairs)
    print("(RR) Reduction ratio is: {0}".format(reduction_ratio))
    print("(PC) Pair completeness is: {0}".format(pair_completeness))
    print("(RM) Reference metric (Harmonic mean RR and PC) is: {0}".format(reference_metric))
    print("(PQ) Pair quality - Precision is: {0}".format(pair_quality))
    print("(FM) Fmeasure is: {0}".format(fmeasure))
    end = time.time()
    blocking_time = end - start
    RR.append(reduction_ratio)
    PC.append(pair_completeness)
    RM.append(reference_metric)
    time_list.append(blocking_time) # blocking time for 30 loops
    print(">> Blocking time was roughly {} seconds for {} tuples!".format(blocking_time,vectors.shape[0]))
    print("*"*50)
    
results["RR"] = RR
results["PC"] = PC
results["RM"] = RM
results["n_neigh"] = range(2,30)
print("Average blocking time is: {}".format(np.average(time_list)))
print("-----------------<<<>>>------------------")
print(f'best results as follows; \n{results.iloc[results["RM"].idxmax()]}')
print(f'dumping or updating results......')
# handle to automatically create paths and save results to csv
# in specified path
directory = "f-measure-results/{}/{}/{}".format(model,dataset, stage)
if not os.path.exists(directory):
    os.makedirs(directory)
    
results.to_csv(directory+"/{}.csv".format(algorithm))
scheme_df = pd.DataFrame(data={"louvain":time_list}) # running times
print(f'done!')
print("check {}.csv file at: {}".format(algorithm,directory))
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'graph_tool'}
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Note: to be able to use all overlapping methods, you need to install some additional packages:  {'ASLPAw'}
#
# building blocks with: 2 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 111886 edges
# graph constructed in: 80.89920711517334  seconds
# (RR) Reduction ratio is: 0.9998772705900302
# (PC) Pair completeness is: 0.4318181818181818
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.6031522755782367
# (PQ) Pair quality - Precision is: 0.00023530383091149273
# (FM) Fmeasure is: 0.0004703513607182348
# >> Blocking time was roughly 81.05881977081299 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 3 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 158845 edges
# graph constructed in: 88.76384711265564  seconds
# (RR) Reduction ratio is: 0.9986860768923211
# (PC) Pair completeness is: 0.5909090909090909
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.7424943076748624
# (PQ) Pair quality - Precision is: 3.0076510014321047e-05
# (FM) Fmeasure is: 6.014995847339405e-05
# >> Blocking time was roughly 90.5699634552002 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 4 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 204626 edges
# graph constructed in: 112.43564081192017  seconds
# (RR) Reduction ratio is: 0.9979015226540472
# (PC) Pair completeness is: 0.6818181818181818
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8101201646894493
# (PQ) Pair quality - Precision is: 2.1729063684988454e-05
# (FM) Fmeasure is: 4.3456742434301854e-05
# >> Blocking time was roughly 115.86323022842407 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 5 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 249677 edges
# graph constructed in: 116.47612190246582  seconds
# (RR) Reduction ratio is: 0.9972653492046516
# (PC) Pair completeness is: 0.7196969696969697
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8360449637188603
# (PQ) Pair quality - Precision is: 1.7600480215207555e-05
# (FM) Fmeasure is: 3.5200099597755494e-05
# >> Blocking time was roughly 121.40242409706116 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 6 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 293551 edges
# graph constructed in: 119.51340365409851  seconds
# (RR) Reduction ratio is: 0.9967625137811248
# (PC) Pair completeness is: 0.7575757575757576
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8608637556733076
# (PQ) Pair quality - Precision is: 1.5649297980317252e-05
# (FM) Fmeasure is: 3.1297949436597784e-05
# >> Blocking time was roughly 125.49997925758362 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 7 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 336488 edges
# graph constructed in: 120.82169795036316  seconds
# (RR) Reduction ratio is: 0.9961856085443989
# (PC) Pair completeness is: 0.7954545454545454
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8845753637128088
# (PQ) Pair quality - Precision is: 1.394655123703917e-05
# (FM) Fmeasure is: 2.789261343826269e-05
# >> Blocking time was roughly 127.88091969490051 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 8 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 378645 edges
# graph constructed in: 117.40256667137146  seconds
# (RR) Reduction ratio is: 0.9958528134416428
# (PC) Pair completeness is: 0.803030303030303
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8891072235088086
# (PQ) Pair quality - Precision is: 1.2949562066579073e-05
# (FM) Fmeasure is: 2.5898706493990705e-05
# >> Blocking time was roughly 125.25091433525085 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 9 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 420178 edges
# graph constructed in: 120.15685796737671  seconds
# (RR) Reduction ratio is: 0.9953224647230019
# (PC) Pair completeness is: 0.8106060606060606
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8935175571412115
# (PQ) Pair quality - Precision is: 1.1589627954529232e-05
# (FM) Fmeasure is: 2.3178924508734065e-05
# >> Blocking time was roughly 129.2535228729248 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 10 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 461253 edges
# graph constructed in: 132.30179810523987  seconds
# (RR) Reduction ratio is: 0.995168057405344
# (PC) Pair completeness is: 0.8333333333333334
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9070889622560586
# (PQ) Pair quality - Precision is: 1.1533834293193003e-05
# (FM) Fmeasure is: 2.306734932040443e-05
# >> Blocking time was roughly 141.6108832359314 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 11 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 502349 edges
# graph constructed in: 144.10406494140625  seconds
# (RR) Reduction ratio is: 0.9944617507655839
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9244434656595876
# (PQ) Pair quality - Precision is: 1.0428819328663967e-05
# (FM) Fmeasure is: 2.0857386794474878e-05
# >> Blocking time was roughly 154.8710217475891 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 12 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 543373 edges
# graph constructed in: 133.97612404823303  seconds
# (RR) Reduction ratio is: 0.9938277594313167
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9241694432499822
# (PQ) Pair quality - Precision is: 9.357606856072291e-06
# (FM) Fmeasure is: 1.8715010932685553e-05
# >> Blocking time was roughly 146.33841013908386 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 13 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 585170 edges
# graph constructed in: 135.59204268455505  seconds
# (RR) Reduction ratio is: 0.9930967153981816
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9238532406302272
# (PQ) Pair quality - Precision is: 8.366655004723858e-06
# (FM) Fmeasure is: 1.6733147903633802e-05
# >> Blocking time was roughly 149.60736751556396 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 14 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 626965 edges
# graph constructed in: 140.7773358821869  seconds
# (RR) Reduction ratio is: 0.9925718617389055
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9279408397445579
# (PQ) Pair quality - Precision is: 7.843694137125098e-06
# (FM) Fmeasure is: 1.568724703887866e-05
# >> Blocking time was roughly 155.94550704956055 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 15 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 669084 edges
# graph constructed in: 144.12892603874207  seconds
# (RR) Reduction ratio is: 0.9919112336034117
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9276520394081162
# (PQ) Pair quality - Precision is: 7.203081616113457e-06
# (FM) Fmeasure is: 1.4406044124710996e-05
# >> Blocking time was roughly 160.53043222427368 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 16 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 711768 edges
# graph constructed in: 158.2422640323639  seconds
# (RR) Reduction ratio is: 0.9912818192898253
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9230671558782924
# (PQ) Pair quality - Precision is: 6.624937310077866e-06
# (FM) Fmeasure is: 1.3249772981411614e-05
# >> Blocking time was roughly 176.15531158447266 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 17 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 754655 edges
# graph constructed in: 154.33047938346863  seconds
# (RR) Reduction ratio is: 0.9895953042037582
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9223352965797532
# (PQ) Pair quality - Precision is: 5.551089795791963e-06
# (FM) Fmeasure is: 1.1102108231921094e-05
# >> Blocking time was roughly 175.9934527873993 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 18 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 797772 edges
# graph constructed in: 159.84939217567444  seconds
# (RR) Reduction ratio is: 0.9898104814265031
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9267323114710433
# (PQ) Pair quality - Precision is: 5.71803703070392e-06
# (FM) Fmeasure is: 1.1435999003377548e-05
# >> Blocking time was roughly 181.3801772594452 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 19 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 841337 edges
# graph constructed in: 188.23212480545044  seconds
# (RR) Reduction ratio is: 0.9891705557726398
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9221507679560452
# (PQ) Pair quality - Precision is: 5.3333670177566034e-06
# (FM) Fmeasure is: 1.0666668163742898e-05
# >> Blocking time was roughly 211.09914803504944 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 20 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 885151 edges
# graph constructed in: 163.4370560646057  seconds
# (RR) Reduction ratio is: 0.9891605612091058
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9221464248774989
# (PQ) Pair quality - Precision is: 5.328449357669452e-06
# (FM) Fmeasure is: 1.065683296498707e-05
# >> Blocking time was roughly 187.3821952342987 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 21 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 929094 edges
# graph constructed in: 190.54596328735352  seconds
# (RR) Reduction ratio is: 0.9885859272568287
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9261952322134107
# (PQ) Pair quality - Precision is: 5.104579744610329e-06
# (FM) Fmeasure is: 1.0209099672372235e-05
# >> Blocking time was roughly 215.2582426071167 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 22 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 973349 edges
# graph constructed in: 180.2166121006012  seconds
# (RR) Reduction ratio is: 0.9874068220817497
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9213836217674104
# (PQ) Pair quality - Precision is: 4.5864039274101e-06
# (FM) Fmeasure is: 9.17275914221345e-06
# >> Blocking time was roughly 208.13552737236023 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 23 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 1017965 edges
# graph constructed in: 169.4329297542572  seconds
# (RR) Reduction ratio is: 0.9874028373277478
# (PC) Pair completeness is: 0.8484848484848485
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9126880182245137
# (PQ) Pair quality - Precision is: 4.504515374474038e-06
# (FM) Fmeasure is: 9.008982921220627e-06
# >> Blocking time was roughly 198.14258980751038 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 24 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 1062583 edges
# graph constructed in: 178.22520208358765  seconds
# (RR) Reduction ratio is: 0.9871619656613659
# (PC) Pair completeness is: 0.8484848484848485
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9125851055980672
# (PQ) Pair quality - Precision is: 4.420000089978574e-06
# (FM) Fmeasure is: 8.839954130109445e-06
# >> Blocking time was roughly 206.2205011844635 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 25 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 1107361 edges
# graph constructed in: 200.07401275634766  seconds
# (RR) Reduction ratio is: 0.9849257176623654
# (PC) Pair completeness is: 0.8560606060606061
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9159830205382868
# (PQ) Pair quality - Precision is: 3.7979092811895403e-06
# (FM) Fmeasure is: 7.595784863711454e-06
# >> Blocking time was roughly 232.6745104789734 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 26 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 1152149 edges
# graph constructed in: 202.3310248851776  seconds
# (RR) Reduction ratio is: 0.9850801807108486
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.920369396553188
# (PQ) Pair quality - Precision is: 3.871186342373085e-06
# (FM) Fmeasure is: 7.742337980286852e-06
# >> Blocking time was roughly 235.55558037757874 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 27 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 1197282 edges
# graph constructed in: 213.759601354599  seconds
# (RR) Reduction ratio is: 0.9836682858523296
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9240312535758237
# (PQ) Pair quality - Precision is: 3.567540063552469e-06
# (FM) Fmeasure is: 7.13505090967401e-06
# >> Blocking time was roughly 249.0493996143341 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 28 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 1242380 edges
# graph constructed in: 211.30137085914612  seconds
# (RR) Reduction ratio is: 0.9836891190480774
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9240404453004099
# (PQ) Pair quality - Precision is: 3.5720967310127607e-06
# (FM) Fmeasure is: 7.144164169910713e-06
# >> Blocking time was roughly 248.14985466003418 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 29 clusters
# using louvian clusterizer
# Graph with 62830 nodes and 1287863 edges
# graph constructed in: 214.662424325943  seconds
# (RR) Reduction ratio is: 0.9819007984370401
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9189793112170116
# (PQ) Pair quality - Precision is: 3.1911573812757888e-06
# (FM) Fmeasure is: 6.382291179830347e-06
# >> Blocking time was roughly 254.3570272922516 seconds for 62830 tuples!
# **************************************************
# Average blocking time is: 171.61560406855173
# -----------------<<<>>>------------------
# best results as follows;
# RR          0.992572
# PC          0.871212
# RM          0.927941
# n_neigh    14.000000
# Name: 12, dtype: float64
# dumping or updating results......
# done!
# check louvian.csv file at: f-measure-results/bert_supCon/DBLP-Scholar-clean/stage_1

# %% [markdown]
# ## LEDEN_clusteriser

# %%
# clusterise using louvain, leiden or markov
algorithm = "leiden"
dataset = 'DBLP-Scholar-clean'
model = "bert_supCon"
stage = "stage_1"
results = pd.DataFrame()
time_list = []
RR = []
PC = []
RM = []
for num_clusters in range(2,30):
    """loop to evaluate cluster performance"""
    # make imports
    from evaluation import calc_index
    from graph_clustering.knn_graph_clusteriser import all_in_one_clusteriser
    key_values = {}
    print()
    key_values["num_clusters"] = num_clusters
    print(f"building blocks with: {num_clusters} clusters")
    start = time.time()
    data = all_in_one_clusteriser(vectors, algorithm, num_clusters)
    reduction_ratio,pair_completeness,reference_metric,pair_quality,fmeasure=calc_index(data,table,pairs)
    print("(RR) Reduction ratio is: {0}".format(reduction_ratio))
    print("(PC) Pair completeness is: {0}".format(pair_completeness))
    print("(RM) Reference metric (Harmonic mean RR and PC) is: {0}".format(reference_metric))
    print("(PQ) Pair quality - Precision is: {0}".format(pair_quality))
    print("(FM) Fmeasure is: {0}".format(fmeasure))
    end = time.time()
    blocking_time = end - start
    RR.append(reduction_ratio)
    PC.append(pair_completeness)
    RM.append(reference_metric)
    time_list.append(blocking_time) # blocking time for 30 loops
    print(">> Blocking time was roughly {} seconds for {} tuples!".format(blocking_time,vectors.shape[0]))
    print("*"*50)
    
results["RR"] = RR
results["PC"] = PC
results["RM"] = RM
results["n_neigh"] = range(2,30)
print("Average blocking time is: {}".format(np.average(time_list)))
print("-----------------<<<>>>------------------")
print(f'best results as follows; \n{results.iloc[results["RM"].idxmax()]}')
print(f'dumping or updating results......')
# handle to automatically create paths and save results to csv
# in specified path
directory = "f-measure-results/{}/{}/{}".format(model,dataset, stage)
if not os.path.exists(directory):
    os.makedirs(directory)
    
results.to_csv(directory+"/{}.csv".format(algorithm)) # precison, recall and f1- score
print(f'done!')
print("check {}.csv file at: {}".format(algorithm,directory))
# Out:
# building blocks with: 2 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 111886 edges
# graph constructed in: 71.33163857460022  seconds
# blocking completed in: 4.2601165771484375  seconds
# (RR) Reduction ratio is: 0.9998772705900302
# (PC) Pair completeness is: 0.4318181818181818
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.6031522755782367
# (PQ) Pair quality - Precision is: 0.00023530383091149273
# (FM) Fmeasure is: 0.0004703513607182348
# >> Blocking time was roughly 84.98406744003296 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 3 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 158845 edges
# graph constructed in: 74.46150279045105  seconds
# blocking completed in: 2.0944221019744873  seconds
# (RR) Reduction ratio is: 0.9985968954125468
# (PC) Pair completeness is: 0.5909090909090909
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.7424696587880173
# (PQ) Pair quality - Precision is: 2.8164843775388982e-05
# (FM) Fmeasure is: 5.6327002804073744e-05
# >> Blocking time was roughly 78.51435947418213 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 4 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 204626 edges
# graph constructed in: 86.8945107460022  seconds
# blocking completed in: 2.8573434352874756  seconds
# (RR) Reduction ratio is: 0.9977635138783827
# (PC) Pair completeness is: 0.6818181818181818
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8100746830715423
# (PQ) Pair quality - Precision is: 2.038820963428989e-05
# (FM) Fmeasure is: 4.077519997970301e-05
# >> Blocking time was roughly 93.47302198410034 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 5 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 249677 edges
# graph constructed in: 88.19549989700317  seconds
# blocking completed in: 3.519530773162842  seconds
# (RR) Reduction ratio is: 0.9971513224163587
# (PC) Pair completeness is: 0.7196969696969697
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8360048914852029
# (PQ) Pair quality - Precision is: 1.689596867522978e-05
# (FM) Fmeasure is: 3.3791144052536334e-05
# >> Blocking time was roughly 96.92440843582153 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 6 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 293551 edges
# graph constructed in: 88.04988670349121  seconds
# blocking completed in: 4.098767280578613  seconds
# (RR) Reduction ratio is: 0.9966852100601323
# (PC) Pair completeness is: 0.7651515151515151
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8657047360787695
# (PQ) Pair quality - Precision is: 1.543718647036068e-05
# (FM) Fmeasure is: 3.087375005253887e-05
# >> Blocking time was roughly 98.25533056259155 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 7 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 336488 edges
# graph constructed in: 89.24636721611023  seconds
# blocking completed in: 4.59971809387207  seconds
# (RR) Reduction ratio is: 0.9960103356057856
# (PC) Pair completeness is: 0.7878787878787878
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8798029043407833
# (PQ) Pair quality - Precision is: 1.3206865741542654e-05
# (FM) Fmeasure is: 2.6413288728738573e-05
# >> Blocking time was roughly 101.17610096931458 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 8 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 378645 edges
# graph constructed in: 89.01772356033325  seconds
# blocking completed in: 5.974992990493774  seconds
# (RR) Reduction ratio is: 0.9957424233430162
# (PC) Pair completeness is: 0.803030303030303
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8890632243123284
# (PQ) Pair quality - Precision is: 1.2613806882616628e-05
# (FM) Fmeasure is: 2.5227217502167516e-05
# >> Blocking time was roughly 103.00187730789185 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 9 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 420178 edges
# graph constructed in: 88.95126700401306  seconds
# blocking completed in: 6.469555616378784  seconds
# (RR) Reduction ratio is: 0.9949790898830473
# (PC) Pair completeness is: 0.8106060606060606
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8933791687609095
# (PQ) Pair quality - Precision is: 1.0797025308530044e-05
# (FM) Fmeasure is: 2.1593762994727994e-05
# >> Blocking time was roughly 104.97533106803894 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 10 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 461253 edges
# graph constructed in: 89.8170256614685  seconds
# blocking completed in: 7.146595001220703  seconds
# (RR) Reduction ratio is: 0.9946803149025694
# (PC) Pair completeness is: 0.8333333333333334
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9068862950982075
# (PQ) Pair quality - Precision is: 1.0476339140431612e-05
# (FM) Fmeasure is: 2.095241487533837e-05
# >> Blocking time was roughly 107.82351732254028 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 11 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 502349 edges
# graph constructed in: 89.74087715148926  seconds
# blocking completed in: 7.943118572235107  seconds
# (RR) Reduction ratio is: 0.9941270142035353
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9242988098276609
# (PQ) Pair quality - Precision is: 9.834418584428613e-06
# (FM) Fmeasure is: 1.9668613198001774e-05
# >> Blocking time was roughly 109.2975013256073 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 12 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 543373 edges
# graph constructed in: 90.55478382110596  seconds
# blocking completed in: 8.515327215194702  seconds
# (RR) Reduction ratio is: 0.9936833015858888
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9241069798128914
# (PQ) Pair quality - Precision is: 9.143605864387973e-06
# (FM) Fmeasure is: 1.828701811802361e-05
# >> Blocking time was roughly 111.80006837844849 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 13 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 585170 edges
# graph constructed in: 90.61432385444641  seconds
# blocking completed in: 10.430930614471436  seconds
# (RR) Reduction ratio is: 0.9928645504066277
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9237527688895889
# (PQ) Pair quality - Precision is: 8.09443047800168e-06
# (FM) Fmeasure is: 1.618870922735125e-05
# >> Blocking time was roughly 115.42151093482971 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 14 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 626965 edges
# graph constructed in: 91.21458339691162  seconds
# blocking completed in: 9.913886785507202  seconds
# (RR) Reduction ratio is: 0.9915476507662392
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9231823914305204
# (PQ) Pair quality - Precision is: 6.833295580374272e-06
# (FM) Fmeasure is: 1.3666483028296034e-05
# >> Blocking time was roughly 118.26672768592834 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 15 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 669084 edges
# graph constructed in: 91.2312912940979  seconds
# blocking completed in: 10.632043361663818  seconds
# (RR) Reduction ratio is: 0.9913496943684814
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9230965822538592
# (PQ) Pair quality - Precision is: 6.676920229545489e-06
# (FM) Fmeasure is: 1.3353737219067823e-05
# >> Blocking time was roughly 119.38830184936523 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 16 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 711768 edges
# graph constructed in: 93.27806305885315  seconds
# blocking completed in: 12.944490671157837  seconds
# (RR) Reduction ratio is: 0.9903166135816623
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9226484700660927
# (PQ) Pair quality - Precision is: 5.964586991329949e-06
# (FM) Fmeasure is: 1.1929091596012522e-05
# >> Blocking time was roughly 125.72199821472168 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 17 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 754655 edges
# graph constructed in: 91.97013783454895  seconds
# blocking completed in: 13.6752450466156  seconds
# (RR) Reduction ratio is: 0.989020417942836
# (PC) Pair completeness is: 0.8560606060606061
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9177498520399705
# (PQ) Pair quality - Precision is: 5.2142929028905316e-06
# (FM) Fmeasure is: 1.0428522285313755e-05
# >> Blocking time was roughly 128.7065372467041 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 18 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 797772 edges
# graph constructed in: 92.50500631332397  seconds
# blocking completed in: 15.976779222488403  seconds
# (RR) Reduction ratio is: 0.9894479828072026
# (PC) Pair completeness is: 0.8560606060606061
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9179338908923923
# (PQ) Pair quality - Precision is: 5.425574631971989e-06
# (FM) Fmeasure is: 1.0851080491538581e-05
# >> Blocking time was roughly 131.9716556072235 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 19 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 841337 edges
# graph constructed in: 92.31480145454407  seconds
# blocking completed in: 13.86668872833252  seconds
# (RR) Reduction ratio is: 0.9878216858910528
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9215642006491577
# (PQ) Pair quality - Precision is: 4.742643369693044e-06
# (FM) Fmeasure is: 9.485234651392667e-06
# >> Blocking time was roughly 132.22927975654602 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 20 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 885151 edges
# graph constructed in: 95.15352487564087  seconds
# blocking completed in: 17.293240547180176  seconds
# (RR) Reduction ratio is: 0.9884048046081448
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9261157332810179
# (PQ) Pair quality - Precision is: 5.024843701144319e-06
# (FM) Fmeasure is: 1.0049629439576734e-05
# >> Blocking time was roughly 138.10942363739014 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 21 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 929094 edges
# graph constructed in: 95.72177743911743  seconds
# blocking completed in: 19.92405390739441  seconds
# (RR) Reduction ratio is: 0.9865297217417909
# (PC) Pair completeness is: 0.8560606060606061
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.916676071450265
# (PQ) Pair quality - Precision is: 4.2501539834549406e-06
# (FM) Fmeasure is: 8.500265764946439e-06
# >> Blocking time was roughly 144.22072649002075 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 22 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 973349 edges
# graph constructed in: 94.2163336277008  seconds
# blocking completed in: 18.694429636001587  seconds
# (RR) Reduction ratio is: 0.9854901082889705
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9205482766531499
# (PQ) Pair quality - Precision is: 3.980553529488726e-06
# (FM) Fmeasure is: 7.961070365910697e-06
# >> Blocking time was roughly 144.08461260795593 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 23 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 1017965 edges
# graph constructed in: 93.95632433891296  seconds
# blocking completed in: 20.273337841033936  seconds
# (RR) Reduction ratio is: 0.9847005696883482
# (PC) Pair completeness is: 0.8560606060606061
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9158856429407831
# (PQ) Pair quality - Precision is: 3.7420188615632837e-06
# (FM) Fmeasure is: 7.484005008984945e-06
# >> Blocking time was roughly 148.22322058677673 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 24 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 1062583 edges
# graph constructed in: 93.85554933547974  seconds
# blocking completed in: 20.474091291427612  seconds
# (RR) Reduction ratio is: 0.9847555238285034
# (PC) Pair completeness is: 0.8560606060606061
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9159094130720606
# (PQ) Pair quality - Precision is: 3.7555083004045047e-06
# (FM) Fmeasure is: 7.510983650383252e-06
# >> Blocking time was roughly 148.08561754226685 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 25 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 1107361 edges
# graph constructed in: 97.22230362892151  seconds
# blocking completed in: 23.90616273880005  seconds
# (RR) Reduction ratio is: 0.9831524514671466
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9195271285392452
# (PQ) Pair quality - Precision is: 3.4282376780341716e-06
# (FM) Fmeasure is: 6.8564481391344135e-06
# >> Blocking time was roughly 158.2306044101715 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 26 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 1152149 edges
# graph constructed in: 94.61289024353027  seconds
# blocking completed in: 28.59047794342041  seconds
# (RR) Reduction ratio is: 0.9833254541345986
# (PC) Pair completeness is: 0.8560606060606061
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.91529038132642
# (PQ) Pair quality - Precision is: 3.4334222508671594e-06
# (FM) Fmeasure is: 6.866816960831281e-06
# >> Blocking time was roughly 161.53815722465515 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 27 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 1197282 edges
# graph constructed in: 95.03405237197876  seconds
# blocking completed in: 26.013726711273193  seconds
# (RR) Reduction ratio is: 0.983285316287645
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9238622484317115
# (PQ) Pair quality - Precision is: 3.485800002618897e-06
# (FM) Fmeasure is: 6.971572111335158e-06
# >> Blocking time was roughly 158.68660259246826 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 28 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 1242380 edges
# graph constructed in: 96.08877921104431  seconds
# blocking completed in: 23.249489068984985  seconds
# (RR) Reduction ratio is: 0.9825063295588087
# (PC) Pair completeness is: 0.8712121212121212
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9235182647324692
# (PQ) Pair quality - Precision is: 3.3305786069406073e-06
# (FM) Fmeasure is: 6.661131748874059e-06
# >> Blocking time was roughly 158.0130259990692 seconds for 62830 tuples!
# **************************************************
#
# building blocks with: 29 clusters
# using leiden clusterizer
# Graph with 62830 nodes and 1287863 edges
# graph constructed in: 95.49081683158875  seconds
# blocking completed in: 27.17963981628418  seconds
# (RR) Reduction ratio is: 0.9821963633219866
# (PC) Pair completeness is: 0.8636363636363636
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.9191087396029267
# (PQ) Pair quality - Precision is: 3.2441349881153674e-06
# (FM) Fmeasure is: 6.488245604000174e-06
# >> Blocking time was roughly 162.3284993171692 seconds for 62830 tuples!
# **************************************************
# Average blocking time is: 124.40900307042259
# -----------------<<<>>>------------------
# best results as follows;
# RR          0.988405
# PC          0.871212
# RM          0.926116
# n_neigh    20.000000
# Name: 18, dtype: float64
# dumping or updating results......
# done!
# check leiden.csv file at: f-measure-results/bert_supCon/DBLP-Scholar-clean/stage_1
